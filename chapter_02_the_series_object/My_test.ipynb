# %%
import pandas as pd
import numpy as np

# %%
ice_creams = [
    "Vanilia",
    "Choco",
    "Strawberry",
    "Rum Raisin"                        
]

# %%
pd.Series(ice_creams,index=ice_creams).head()
# Out:
# Vanilia          Vanilia
# Choco              Choco
# Strawberry    Strawberry
# Rum Raisin    Rum Raisin
# dtype: object

# %%
numbers = pd.Series([1,2,3,np.nan,4,5],dtype=pd.Int32Dtype())
numbers
# Out:
# 0       1
# 1       2
# 2       3
# 3    <NA>
# 4       4
# 5       5
# dtype: Int32

# %%
numbers.sum(min_count=5)
# Out:
# np.int64(15)

# %%
s = pd.Series([2,2,4,4])
s.var(ddof=3)
# Out:
# np.float64(4.0)
