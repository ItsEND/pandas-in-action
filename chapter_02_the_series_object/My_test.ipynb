# %%
import pandas as pd
import numpy as np

# %%
ice_creams = [
    "Vanilia",
    "Choco",
    "Strawberry",
    "Rum Raisin"                        
]

# %%
pd.Series(ice_creams,index=ice_creams).head()
# Out:
# Vanilia          Vanilia
# Choco              Choco
# Strawberry    Strawberry
# Rum Raisin    Rum Raisin
# dtype: object

# %%
pd.Series(fa)
